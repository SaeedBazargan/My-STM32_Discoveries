# %%
# %tensorflow_version 2.1
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import math
from tensorflow.keras import layers

# %%
# Settings
nsamples = 1000     # Number of samples to use as a dataset
val_ratio = 0.2     # Percentage of samples that should be held for validation set
test_ratio = 0.2    # Percentage of samples that should be held for test set
tflite_model_name = 'sine_model'  # Will be given .tflite suffix
c_model_name = 'sine_model'       # Will be given .h suffix

# %%
# Generate some random samples
np.random.seed(1234)
x_values = np.random.uniform(low=0, high=(2 * math.pi), size=nsamples)
plt.plot(x_values)

# %%
# Create a noisy sinewave with these values
y_values = np.sin(x_values) + (0.1 * np.random.randn(x_values.shape[0]))
plt.plot(x_values, y_values, '.')

# %%
# Plit the dataset into training, validation, and test sets
val_split = int(val_ratio * nsamples)
test_split = int(val_split + (test_ratio * nsamples))
x_val, x_test, x_train = np.split(x_values, [val_split, test_split])
y_val, y_test, y_train = np.split(y_values, [val_split, test_split])

# Check that our splits add up correctly
assert(x_train.size + x_val.size + x_test.size) == nsamples

# Plot the data in each partition in different colors:
plt.plot(x_train, y_train, 'b.', label="Train")
plt.plot(x_test, y_test, 'r.', label="Test")
plt.plot(x_val, y_val, 'y.', label="Validate")
plt.legend()
plt.show()

# %%
# Create a model
model = tf.keras.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(1,)))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# View model
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │            32 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 321 (1.25 KB)
#  Trainable params: 321 (1.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Add optimizer, loss function, and metrics to model and compile it
model.compile(optimizer='rmsprop', loss='mae', metrics=['mae'])

# %%
# Train model
history = model.fit(x_train,
                    y_train,
                    epochs=200,
                    batch_size=100,
                    validation_data=(x_val, y_val))
# Out:
# Epoch 1/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2846 - mae: 0.2846 - val_loss: 0.3151 - val_mae: 0.3151
# Epoch 2/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2986 - mae: 0.2986 - val_loss: 0.3176 - val_mae: 0.3176
# Epoch 3/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.2906 - mae: 0.2906 - val_loss: 0.3243 - val_mae: 0.3243
# Epoch 4/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2900 - mae: 0.2900 - val_loss: 0.3183 - val_mae: 0.3183
# Epoch 5/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2976 - mae: 0.2976 - val_loss: 0.3160 - val_mae: 0.3160
# Epoch 6/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3021 - mae: 0.3021 - val_loss: 0.3187 - val_mae: 0.3187
# Epoch 7/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2982 - mae: 0.2982 - val_loss: 0.3188 - val_mae: 0.3188
# Epoch 8/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2769 - mae: 0.2769 - val_loss: 0.3214 - val_mae: 0.3214
# Epoch 9/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2895 - mae: 0.2895 - val_loss: 0.3238 - val_mae: 0.3238
# Epoch 10/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2995 - mae: 0.2995 - val_loss: 0.3283 - val_mae: 0.3283
# Epoch 11/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2954 - mae: 0.2954 - val_loss: 0.3210 - val_mae: 0.3210
# Epoch 12/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3003 - mae: 0.3003 - val_loss: 0.3204 - val_mae: 0.3204
# Epoch 13/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3002 - mae: 0.3002 - val_loss: 0.3244 - val_mae: 0.3244
# Epoch 14/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2981 - mae: 0.2981 - val_loss: 0.3211 - val_mae: 0.3211
# Epoch 15/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2940 - mae: 0.2940 - val_loss: 0.3223 - val_mae: 0.3223
# Epoch 16/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3017 - mae: 0.3017 - val_loss: 0.3185 - val_mae: 0.3185
# Epoch 17/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3030 - mae: 0.3030 - val_loss: 0.3196 - val_mae: 0.3196
# Epoch 18/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2889 - mae: 0.2889 - val_loss: 0.3257 - val_mae: 0.3257
# Epoch 19/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2924 - mae: 0.2924 - val_loss: 0.3251 - val_mae: 0.3251
# Epoch 20/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2966 - mae: 0.2966 - val_loss: 0.3163 - val_mae: 0.3163
# Epoch 21/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2988 - mae: 0.2988 - val_loss: 0.3175 - val_mae: 0.3175
# Epoch 22/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2913 - mae: 0.2913 - val_loss: 0.3167 - val_mae: 0.3167
# Epoch 23/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.
# Epoch 178/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2909 - mae: 0.2909 - val_loss: 0.3216 - val_mae: 0.3216
# Epoch 179/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2982 - mae: 0.2982 - val_loss: 0.3199 - val_mae: 0.3199
# Epoch 180/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2884 - mae: 0.2884 - val_loss: 0.3188 - val_mae: 0.3188
# Epoch 181/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2901 - mae: 0.2901 - val_loss: 0.3204 - val_mae: 0.3204
# Epoch 182/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.2894 - mae: 0.2894 - val_loss: 0.3216 - val_mae: 0.3216
# Epoch 183/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2900 - mae: 0.2900 - val_loss: 0.3204 - val_mae: 0.3204
# Epoch 184/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2829 - mae: 0.2829 - val_loss: 0.3207 - val_mae: 0.3207
# Epoch 185/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2905 - mae: 0.2905 - val_loss: 0.3206 - val_mae: 0.3206
# Epoch 186/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3044 - mae: 0.3044 - val_loss: 0.3164 - val_mae: 0.3164
# Epoch 187/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3048 - mae: 0.3048 - val_loss: 0.3181 - val_mae: 0.3181
# Epoch 188/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2826 - mae: 0.2826 - val_loss: 0.3189 - val_mae: 0.3189
# Epoch 189/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2940 - mae: 0.2940 - val_loss: 0.3195 - val_mae: 0.3195
# Epoch 190/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2936 - mae: 0.2936 - val_loss: 0.3310 - val_mae: 0.3310
# Epoch 191/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3027 - mae: 0.3027 - val_loss: 0.3255 - val_mae: 0.3255
# Epoch 192/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2878 - mae: 0.2878 - val_loss: 0.3289 - val_mae: 0.3289
# Epoch 193/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3028 - mae: 0.3028 - val_loss: 0.3206 - val_mae: 0.3206
# Epoch 194/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2930 - mae: 0.2930 - val_loss: 0.3236 - val_mae: 0.3236
# Epoch 195/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2956 - mae: 0.2956 - val_loss: 0.3213 - val_mae: 0.3213
# Epoch 196/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.2886 - mae: 0.2886 - val_loss: 0.3247 - val_mae: 0.3247
# Epoch 197/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2989 - mae: 0.2989 - val_loss: 0.3199 - val_mae: 0.3199
# Epoch 198/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.2828 - mae: 0.2828 - val_loss: 0.3175 - val_mae: 0.3175
# Epoch 199/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.2981 - mae: 0.2981 - val_loss: 0.3202 - val_mae: 0.3202
# Epoch 200/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3027 - mae: 0.3027 - val_loss: 0.3219 - val_mae: 0.3219

# %%
# Plot the training history
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
# Plot predictions against actual values
predictions = model.predict(x_test)

plt.clf()
plt.title("Comparison of predictions to actual values")
plt.plot(x_test, y_test, 'b.', label='Actual')
plt.plot(x_test, predictions, 'r.', label='Prediction')
plt.legend()
plt.show()
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
# Convert Keras model to a tflite model
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.OPTIMIZE_FOR_SIZE]
tflite_model = converter.convert()

open(tflite_model_name + '.tflite', 'wb').write(tflite_model)
# Out:
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# Saved artifact at '/tmp/tmpvd3q8p5t'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 1), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   132551940678544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132551940679696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132551940678928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132551940677008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132551940676624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132551940677392: TensorSpec(shape=(), dtype=tf.resource, name=None)
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# 3168

# %%
# Function: Convert some hex value into an array for C programming
def hex_to_c_array(hex_data, var_name):

  c_str = ''

  # Create header guard
  c_str += '#ifndef ' + var_name.upper() + '_H\n'
  c_str += '#define ' + var_name.upper() + '_H\n\n'

  # Add array length at top of file
  c_str += '\nunsigned int ' + var_name + '_len = ' + str(len(hex_data)) + ';\n'

  # Declare C variable
  c_str += 'unsigned char ' + var_name + '[] = {'
  hex_array = []
  for i, val in enumerate(hex_data) :

    # Construct string from hex
    hex_str = format(val, '#04x')

    # Add formatting so each line stays within 80 characters
    if (i + 1) < len(hex_data):
      hex_str += ','
    if (i + 1) % 12 == 0:
      hex_str += '\n '
    hex_array.append(hex_str)

  # Add closing brace
  c_str += '\n ' + format(' '.join(hex_array)) + '\n};\n\n'

  # Close out header guard
  c_str += '#endif //' + var_name.upper() + '_H'

  return c_str

# %%
# Write TFLite model to a C source (or header) file
with open(c_model_name + '.h', 'w') as file:
  file.write(hex_to_c_array(tflite_model, c_model_name))
